# %%
import os

print(os.path.exists("../models/encoder.pkl"))
print(os.path.exists("../models/kmeans_model.pkl"))
print(os.path.exists("../outputs/final_clustered_data.csv"))
# Out:
# True
# True
# True

# %%
recommend_restaurants("AB FOODS POINT")
# Out:
#                        name    city                     cuisine rating
# 1         Janta Sweet House  Abohar               Sweets,Bakery    4.4
# 3                 Singh Hut  Abohar            Fast Food,Indian    3.7
# 4             GRILL MASTERS  Abohar  Italian-American,Fast Food     --
# 5                 Sam Uncle  Abohar                 Continental    3.6
# 8  Hinglaj Kachori Bhandhar  Abohar                Snacks,Chaat    4.2

# %%
cleaned_df['name'].iloc[0]
# Out:
# 'AB FOODS POINT'

# %%
def recommend_restaurants(restaurant_name, n=5):

    if restaurant_name not in restaurant_indices:
        return "Restaurant not found"

    idx = restaurant_indices[restaurant_name]

    cluster = cleaned_df.loc[idx, 'cluster']

    recommendations = cleaned_df[
        (cleaned_df['cluster'] == cluster) &
        (cleaned_df.index != idx)
    ]

    return recommendations[
        ['name', 'city', 'cuisine', 'rating']
    ].head(n)

# %%
restaurant_indices = pd.Series(
    cleaned_df.index,
    index=cleaned_df['name']
).drop_duplicates()

# %%
import joblib

joblib.dump(kmeans, "../models/kmeans_model.pkl")
# Out:
# ['../models/kmeans_model.pkl']

# %%
cleaned_df.to_csv("../outputs/final_clustered_data.csv", index=False)

# %%
cleaned_df[['name', 'city', 'cuisine', 'cluster']].head()
# Out:
#                 name    city                     cuisine  cluster
# 0     AB FOODS POINT  Abohar            Beverages,Pizzas        0
# 1  Janta Sweet House  Abohar               Sweets,Bakery        0
# 2  theka coffee desi  Abohar                   Beverages       40
# 3          Singh Hut  Abohar            Fast Food,Indian        0
# 4      GRILL MASTERS  Abohar  Italian-American,Fast Food        0

# %%
cleaned_df['cluster'] = clusters

# %%
kmeans = MiniBatchKMeans(
    n_clusters=20,
    random_state=42,
    batch_size=1000
)

# %%
kmeans = MiniBatchKMeans(
    n_clusters=50,
    random_state=42,
    batch_size=1000
)

# %%
from sklearn.cluster import MiniBatchKMeans

# %%
cleaned_df.shape
# Out:
# (148255, 12)

# %%
encoded_df.shape
# Out:
# (148255, 2952)

# %%
import pandas as pd

# %%
from sklearn.cluster import MiniBatchKMeans

# %%
import pandas as pd

# %%
encoded_df = pd.read_csv("../outputs/encoded_data.csv")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[163], line 1
# ----> 1 encoded_df = pd.read_csv("../outputs/encoded_data.csv")
#
# File c:\Users\diya1\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
import pandas as pd

cleaned_df = pd.read_csv("../outputs/cleaned_data.csv")

# %%
len(cleaned_df), len(encoded_df)
# Out:
# (148255, 148255)

# %%
encoded_df.shape
# Out:
# (148255, 2952)

# %%
import pandas as pd

encoded_df = pd.DataFrame(encoded_features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 import pandas as pd
# ----> 3 encoded_df = pd.DataFrame(encoded_features)
#
# NameError: name 'encoded_features' is not defined

# %%
import os
os.path.exists("../models/encoder.pkl")

# %%
import pickle

with open("../models/encoder.pkl", "wb") as f:
    pickle.dump(encoder, f)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
encoded_df.head()

# %%
encoded_df.to_csv("../outputs/encoded_data.csv", index=False)

# %%
encoded_df.shape

# %%
encoded_df = pd.DataFrame(encoded_features)

# %%
type(encoded_features)

# %%
encoded_features = encoder.fit_transform(cleaned_df[['city', 'cuisine']])

# %%
encoded_features.shape

# %%
encoded_features = encoder.fit_transform(cleaned_df[['city', 'cuisine']])

# %%
encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
cleaned_df.to_csv("../outputs/cleaned_data.csv", index=False)

# %%
cleaned_df.shape

# %%
cleaned_df = df.dropna()

# %%
df.duplicated().sum()

# %%
df.isnull().sum()

# %%
df.columns

# %%
df.shape

# %%
df = pd.read_csv("../data/swiggy.csv")

# %%
import pandas as pd
